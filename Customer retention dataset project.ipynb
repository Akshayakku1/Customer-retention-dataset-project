# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_excel(r"C:\Users\User\Desktop\Akshay project\Data set\customer_retention_dataset.xlsx")

# %%
data.head()
# Out:
#   1Gender of respondent 2 How old are you?   \
# 0                  Male         31-40 years
# 1                Female         21-30 years
# 2                Female         21-30 years
# 3                  Male         21-30 years
# 4                Female         21-30 years
#
#   3 Which city do you shop online from?  \
# 0                                 Delhi
# 1                                 Delhi
# 2                         Greater Noida
# 3                               Karnal
# 4                            Bangalore
#
#    4 What is the Pin Code of where you shop online from?  \
# 0                                             110009
# 1                                             110030
# 2                                             201308
# 3                                             132001
# 4                                             530068
#
#   5 Since How Long You are Shopping Online ?  \
# 0                              Above 4 years
# ...

# %%
data.shape
# Out:
# (269, 71)

# %%
data.columns.values
# Out:
# array(['1Gender of respondent', '2 How old are you? ',
#        '3 Which city do you shop online from?',
#        '4 What is the Pin Code of where you shop online from?',
#        '5 Since How Long You are Shopping Online ?',
#        '6 How many times you have made an online purchase in the past 1 year?',
#        '7 How do you access the internet while shopping on-line?',
#        '8 Which device do you use to access the online shopping?',
#        '9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ',
#        '10 What is the operating system (OS) of your device?\t\t\t\t                                          ',
#        '11 What browser do you run on your device to access the website?\t\t\t                                                          ',
#        '12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ',
# ...

# %%
#Let me check for the missing values
data.isna().sum()
# Out:
# 1Gender of respondent                                                   0
# 2 How old are you?                                                      0
# 3 Which city do you shop online from?                                   0
# 4 What is the Pin Code of where you shop online from?                   0
# 5 Since How Long You are Shopping Online ?                              0
#                                                                        ..
# Longer delivery period                                                  0
# Change in website/Application design                                    0
# Frequent disruption when moving from one page to another                0
# Website is as efficient as before                                       0
# Which of the Indian online retailer would you recommend to a friend?    0
# Length: 71, dtype: int64

# %%
data.nunique()
# Out:
# 1Gender of respondent                                                    2
# 2 How old are you?                                                       5
# 3 Which city do you shop online from?                                   11
# 4 What is the Pin Code of where you shop online from?                   39
# 5 Since How Long You are Shopping Online ?                               5
#                                                                         ..
# Longer delivery period                                                   6
# Change in website/Application design                                     7
# Frequent disruption when moving from one page to another                 8
# Website is as efficient as before                                        8
# Which of the Indian online retailer would you recommend to a friend?     8
# Length: 71, dtype: int64

# %%
data['1Gender of respondent'].replace({'Male':0,'Female':1},inplace=True)

# %%
data.head()
# Out:
#    1Gender of respondent 2 How old are you?   \
# 0                      0         31-40 years
# 1                      1         21-30 years
# 2                      1         21-30 years
# 3                      0         21-30 years
# 4                      1         21-30 years
#
#   3 Which city do you shop online from?  \
# 0                                 Delhi
# 1                                 Delhi
# 2                         Greater Noida
# 3                               Karnal
# 4                            Bangalore
#
#    4 What is the Pin Code of where you shop online from?  \
# 0                                             110009
# 1                                             110030
# 2                                             201308
# 3                                             132001
# 4                                             530068
#
#   5 Since How Long You are Shopping Online ?  \
# 0                              Above 4 years
# ...

# %%
data.dtypes
# Out:
# 1Gender of respondent                                                    int64
# 2 How old are you?                                                      object
# 3 Which city do you shop online from?                                   object
# 4 What is the Pin Code of where you shop online from?                    int64
# 5 Since How Long You are Shopping Online ?                              object
#                                                                          ...
# Longer delivery period                                                  object
# Change in website/Application design                                    object
# Frequent disruption when moving from one page to another                object
# Website is as efficient as before                                       object
# Which of the Indian online retailer would you recommend to a friend?    object
# Length: 71, dtype: object

# %%
data.value_counts('2 How old are you? ')
# Out:
# 2 How old are you?
# 31-40 years           81
# 21-30 years           79
# 41-50 yaers           70
# Less than 20 years    20
# 51 years and above    19
# dtype: int64

# %%
data['2 How old are you? '].replace({'Less than 20 years':"Teenage",'21-30 years':"Teenage",'31-40 years':"Mid-Age",'41-50 yaers':"Mid-Age",'51 years and above':"Above 50"},inplace=True)

# %%
data.value_counts('2 How old are you? ')
# Out:
# 2 How old are you?
# Mid-Age     151
# Teenage      99
# Above 50     19
# dtype: int64

# %%
data.value_counts('4 What is the Pin Code of where you shop online from?')
# Out:
# 4 What is the Pin Code of where you shop online from?
# 201308    38
# 132001    19
# 201310    18
# 110044    16
# 250001     9
# 173212     9
# 173229     9
# 560037     8
# 560010     8
# 122018     8
# 132036     8
# 110011     7
# 201306     7
# 110008     7
# 110014     6
# 110018     6
# 201312     5
# 201009     5
# 244001     5
# 201008     5
# 530068     5
# 201305     5
# 560018     4
# 122009     4
# 110009     4
# 110030     4
# 110039     4
# 110042     4
# 201005     4
# 560003     4
# 560002     4
# 201304     4
# 201001     4
# 201303     4
# 560013     3
# 203001     2
# 560001     1
# 203207     1
# 203202     1
# dtype: int64

# %%
data.value_counts('5 Since How Long You are Shopping Online ?')
# Out:
# 5 Since How Long You are Shopping Online ?
# Above 4 years       98
# 2-3 years           65
# 3-4 years           47
# Less than 1 year    43
# 1-2 years           16
# dtype: int64

# %%
data.value_counts('6 How many times you have made an online purchase in the past 1 year?')
# Out:
# 6 How many times you have made an online purchase in the past 1 year?
# Less than 10 times    114
# 31-40 times            63
# 41 times and above     47
# 11-20 times            29
# 21-30 times            10
# 42 times and above      6
# dtype: int64

# %%
data['6 How many times you have made an online purchase in the past 1 year?'].replace({'Less than 10 times':"Minimum",'11-20 times':"Minimum",'21-30 times':"Medium",'31-40 times':"Medium",'41 times and above':"Maximum",'42 times and above':"Maximum"},inplace=True)

# %%
data.value_counts('6 How many times you have made an online purchase in the past 1 year?')
# Out:
# 6 How many times you have made an online purchase in the past 1 year?
# Minimum    143
# Medium      73
# Maximum     53
# dtype: int64

# %%
data.head()
# Out:
#    1Gender of respondent 2 How old are you?   \
# 0                      0             Mid-Age
# 1                      1             Teenage
# 2                      1             Teenage
# 3                      0             Teenage
# 4                      1             Teenage
#
#   3 Which city do you shop online from?  \
# 0                                 Delhi
# 1                                 Delhi
# 2                         Greater Noida
# 3                               Karnal
# 4                            Bangalore
#
#    4 What is the Pin Code of where you shop online from?  \
# 0                                             110009
# 1                                             110030
# 2                                             201308
# 3                                             132001
# 4                                             530068
#
#   5 Since How Long You are Shopping Online ?  \
# 0                              Above 4 years
# ...

# %%
data.value_counts('7 How do you access the internet while shopping on-line?')
# Out:
# 7 How do you access the internet while shopping on-line?
# Mobile internet    142
# Wi-Fi               76
# Mobile Internet     47
# Dial-up              4
# dtype: int64

# %%
from sklearn.preprocessing import StandardScaler,LabelEncoder

# %%
data=data.drop(['Easy to use website or application',
       'Visual appealing web-page layout',
       'Wild variety of product on offer',
       'Complete, relevant description information of products',
       'Fast loading website speed of website and application',
       'Reliability of the website or application',
       'Quickness to complete purchase',
       'Availability of several payment options',
       'Speedy order delivery ', 'Privacy of customers’ information',
       'Security of customer financial information',
       'Perceived Trustworthiness',
       'Presence of online assistance through multi-channel',
       'Longer time to get logged in (promotion, sales period)',
       'Longer time in displaying graphics and photos (promotion, sales period)',
       'Late declaration of price (promotion, sales period)',
       'Longer page loading time (promotion, sales period)',
       'Limited mode of payment on most products (promotion, sales period)',
       'Longer delivery period', 'Change in website/Application design',
       'Frequent disruption when moving from one page to another',
       'Website is as efficient as before'],axis=1)

# %%
#just creating and keeping a data for myself
data1=data.copy()
data1=data1.apply(LabelEncoder().fit_transform)
data1.head()
# Out:
#    1Gender of respondent  2 How old are you?   \
# 0                      0                    1
# 1                      1                    2
# 2                      1                    2
# 3                      0                    2
# 4                      1                    2
#
#    3 Which city do you shop online from?  \
# 0                                      2
# 1                                      2
# 2                                      4
# 3                                      6
# 4                                      0
#
#    4 What is the Pin Code of where you shop online from?  \
# 0                                                  1
# 1                                                  5
# 2                                                 23
# 3                                                 11
# 4                                                 31
#
#    5 Since How Long You are Shopping Online ?  \
# 0                                           3
# ...

# %%
x = data1.drop(columns=['Which of the Indian online retailer would you recommend to a friend?'])
y= data1['Which of the Indian online retailer would you recommend to a friend?']

# %%
from sklearn.preprocessing import StandardScaler
from statsmodels.stats.outliers_influence import variance_inflation_factor

scalar = StandardScaler()
x_scaled = scalar.fit_transform(x)

vif = pd.DataFrame()
vif["vif"] = [variance_inflation_factor(x_scaled,i) for i in range(x_scaled.shape[1])]
vif["Features"] = x.columns

vif
# Out:
#           vif                                           Features
# 0    2.346868                              1Gender of respondent
# 1    1.432731                                2 How old are you?
# 2    1.598368              3 Which city do you shop online from?
# 3    1.667173  4 What is the Pin Code of where you shop onlin...
# 4    1.690236         5 Since How Long You are Shopping Online ?
# 5    1.467896  6 How many times you have made an online purch...
# 6    2.235739  7 How do you access the internet while shoppin...
# 7   38.062520  8 Which device do you use to access the online...
# 8   30.135626  9 What is the screen size of your mobile devic...
# 9   38.889755  10 What is the operating system (OS) of your d...
# 10        inf  11 What browser do you run on your device to a...
# 11        inf  12 Which channel did you follow to arrive at y...
# 12        inf  13 After first visit, how do you reach the onl...
# ...
